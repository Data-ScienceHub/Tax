# %% [markdown]
# # Metadata
#
# ### Title: AK_query_v2_demo
# ### Author: Ami Kano
# ### Date: February 12, 2023
#
# #### Comments:
# This .ipynb file is used to demonstrate the use of the queries_v2 Python package.
#
# The MongoDB database with accessed with the author's credentials.
#
# To be run without error, this file requires the Python packages PyMongo, NumPy, and Pandas.

# %%
import queries_v2.queries_v2 as q2
# Out:
# Welcome to Query Ver2.0.

# %% [markdown]
# ### Example 1

# %%
result_1 = q2.query(first_name="George", 
         last_name="Thompson", 
         date_range=[1600, 1900], 
         location="", 
         source="any", 
         include="not all")

# %%
len(result_1)
# Out:
# 2

# %%
result_1[0]
# Out:
#                           _id        SourceSteward SourceLocCity  \
# 0    63e9361e59c84387372abcf0  Library of Virginia      Richmond
# 1    63e9361e59c84387372abd35  Library of Virginia      Richmond
# 2    63e9361e59c84387372abd56  Library of Virginia      Richmond
# 3    63e9361e59c84387372abd63  Library of Virginia      Richmond
# 4    63e9361e59c84387372abda9  Library of Virginia      Richmond
# ..                        ...                  ...           ...
# 347  63e9362759c84387372aec97  Library of Virginia      Richmond
# 348  63e9362759c84387372aeca6  Library of Virginia      Richmond
# 349  63e9362759c84387372aecc4  Library of Virginia      Richmond
# 350  63e9362759c84387372aecc7  Library of Virginia      Richmond
# 351  63e9362759c84387372aecf3  Library of Virginia      Richmond
#
#     SourceLocState                     SourceTitle         SourceType  \
# 0         Virginia  County Personal Property Taxes  Government Record
# ...

# %% [markdown]
# ### Example 2

# %%
result_2 = q2.query(first_name="George", 
         last_name="Thompson", 
         source="1782 Tax Record")

# %%
result_2
# Out:
#                           _id                       SourceSteward  \
# 0    63e9351559c84387372ab950  Fluvanna County Historical Society
# 1    63e9351559c84387372ab951  Fluvanna County Historical Society
# 2    63e9351559c84387372ab952  Fluvanna County Historical Society
# 3    63e9351559c84387372ab953  Fluvanna County Historical Society
# 4    63e9351559c84387372ab954  Fluvanna County Historical Society
# ..                        ...                                 ...
# 857  63e9351559c84387372abca9  Fluvanna County Historical Society
# 858  63e9351559c84387372abcaa  Fluvanna County Historical Society
# 859  63e9351559c84387372abcab  Fluvanna County Historical Society
# 860  63e9351559c84387372abcac  Fluvanna County Historical Society
# 861  63e9351559c84387372abcad  Fluvanna County Historical Society
#
#     SourceLocCity SourceLocState                     SourceTitle  \
# 0         Palmyra       Virginia  County Personal Property Taxes
# ...

# %% [markdown]
# ### Example 3

# %%
result_3 = q2.query()

# %%
len(result_3)
# Out:
# 2

# %%
result_3[0]
# Out:
#                             _id        SourceSteward SourceLocCity  \
# 0      63e9361e59c84387372abcaf  Library of Virginia      Richmond
# 1      63e9361e59c84387372abcb0  Library of Virginia      Richmond
# 2      63e9361e59c84387372abcb1  Library of Virginia      Richmond
# 3      63e9361e59c84387372abcb2  Library of Virginia      Richmond
# 4      63e9361e59c84387372abcb3  Library of Virginia      Richmond
# ...                         ...                  ...           ...
# 12358  63e9362759c84387372aecf5  Library of Virginia      Richmond
# 12359  63e9362759c84387372aecf6  Library of Virginia      Richmond
# 12360  63e9362759c84387372aecf7  Library of Virginia      Richmond
# 12361  63e9362759c84387372aecf8  Library of Virginia      Richmond
# 12362  63e9362759c84387372aecf9  Library of Virginia      Richmond
#
#       SourceLocState                     SourceTitle         SourceType  \
# 0           Virginia  County Personal Property Taxes  Government Record
# ...
