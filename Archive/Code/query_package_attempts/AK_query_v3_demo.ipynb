# %% [markdown]
# # Metadata
#
# ### Title: AK_query_v3
# ### Author: Ami Kano
# ### Date: February 19, 2023
#
# #### Comments:
# This .ipynb file is used to demonstrate the use of the queries_v3 Python package.
#
# The MongoDB database with accessed with the author's credentials.
#
# To be run without error, this file requires the Python packages PyMongo, NumPy, and Pandas.

# %%
import queries_v3.queries_v3 as q3
# Out:
# Welcome to Query Ver3.0.

# %% [markdown]
# ### Example 1

# %%
res1 = q3.query(given_name="John", 
      surname="Richardson", 
      date_range=[1600, 1900], 
      location="", 
      source="any", 
      wide=False)

# %%
len(res1)
# Out:
# 2

# %%
res1[0]
# Out:
#                         _id        SourceSteward SourceLocCity SourceLocState  \
# 0  63e9362259c84387372ad639  Library of Virginia      Richmond       Virginia
# 1  63e9362459c84387372adcc7  Library of Virginia      Richmond       Virginia
# 2  63e9362459c84387372adcd4  Library of Virginia      Richmond       Virginia
# 3  63e9362459c84387372adcf1  Library of Virginia      Richmond       Virginia
# 4  63e9362459c84387372adcf8  Library of Virginia      Richmond       Virginia
# 5  63e9362459c84387372adcf9  Library of Virginia      Richmond       Virginia
# 6  63e9362459c84387372adcfa  Library of Virginia      Richmond       Virginia
# 7  63e9362459c84387372adcfb  Library of Virginia      Richmond       Virginia
# 8  63e9362459c84387372add00  Library of Virginia      Richmond       Virginia
# 9  63e9362659c84387372aea88  Library of Virginia      Richmond       Virginia
#
#                       SourceTitle         SourceType  SourceDateYearCreated  \
# ...

# %%
res1[1]
# Out:
#                         _id                       SourceSteward SourceLocCity  \
# 0  63e9351559c84387372ab950  Fluvanna County Historical Society       Palmyra
# 1  63e9351559c84387372abbe2  Fluvanna County Historical Society       Palmyra
# 2  63e9351559c84387372abbea  Fluvanna County Historical Society       Palmyra
# 3  63e9351559c84387372abbfc  Fluvanna County Historical Society       Palmyra
# 4  63e9351559c84387372abbfd  Fluvanna County Historical Society       Palmyra
# 5  63e9351559c84387372abbfe  Fluvanna County Historical Society       Palmyra
# 6  63e9351559c84387372abbff  Fluvanna County Historical Society       Palmyra
# 7  63e9351559c84387372abc00  Fluvanna County Historical Society       Palmyra
# 8  63e9351559c84387372abc0a  Fluvanna County Historical Society       Palmyra
#
#   SourceLocState                     SourceTitle         SourceType  \
# 0       Virginia  County Personal Property Taxes  Government Record
# ...

# %% [markdown]
# ### Example 2

# %%
res2 = q3.query(given_name="Jos", 
      surname="Haden", 
      date_range=[1600, 1900], 
      location="", 
      source="Tax_Record_1867", 
      wide=False)

# %%
len(res2)
# Out:
# 1

# %%
res2[0]
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Example 3

# %%
res3 = q3.query(given_name="Emily", 
      surname="", 
      date_range=[1600, 1900], 
      location="", 
      source="any", 
      wide=False)

# %%
len(res3)
# Out:
# 2

# %%
res3[0]
# Out:
#                         _id        SourceSteward SourceLocCity SourceLocState  \
# 0  63e9362559c84387372ae3e8  Library of Virginia      Richmond       Virginia
#
#                       SourceTitle         SourceType  SourceDateYearCreated  \
# 0  County Personal Property Taxes  Government Record                   1867
#
#               SourceCreator SourceLocCreatedCounty SourceAuthorName  ...  \
# 0  Louisa County District 2                 Louisa    Robert F Moss  ...
#
#   PersonTaxValueCattle PersonTaxCountHogs  PersonTaxValueHogs  \
# 0                   50                  5                  20
#
#   PersonTaxCountCarriageWagon PersonTaxValueCarriageWagon  \
# 0                           1                          50
#
#   PersonTaxValueClocks PersonTaxValueFurnishings  \
# 0                    5                        75
#
#    PersonTaxValueAggregatePersonlProperty  PersonTaxStateAll  \
# 0                                     400                1.2
#
# ...

# %%
res3[1]
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## TO-DO / Improvements
#
# - rid wide search altogether?
#   - do not include empty search inputs?
# - make function less prone to errors
