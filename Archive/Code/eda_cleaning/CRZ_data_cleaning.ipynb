# %% [markdown]
# # Data Cleaning
#
# Rachel Grace Treene | 4/7/23
#
# This notebook handles missing values in the data based on the type of data in each feature.

# %%
import pandas as pd
import numpy as np

data = pd.read_excel("CentralVA1867PPTaxAllrev5flatuvasds.xlsx")

# %%
data
# Out:
#              SourceSteward SourceLocCity SourceLocState  \
# 0      Library of Virginia      Richmond       Virginia
# 1      Library of Virginia      Richmond       Virginia
# 2      Library of Virginia      Richmond       Virginia
# 3      Library of Virginia      Richmond       Virginia
# 4      Library of Virginia      Richmond       Virginia
# ...                    ...           ...            ...
# 12358  Library of Virginia      Richmond       Virginia
# 12359  Library of Virginia      Richmond       Virginia
# 12360  Library of Virginia      Richmond       Virginia
# 12361  Library of Virginia      Richmond       Virginia
# 12362  Library of Virginia      Richmond       Virginia
#
#                           SourceTitle         SourceType  \
# 0      County Personal Property Taxes  Government Record
# 1      County Personal Property Taxes  Government Record
# 2      County Personal Property Taxes  Government Record
# 3      County Personal Property Taxes  Government Record
# 4      County Personal Property Taxes  Government Record
# ...                               ...                ...
# 12358  County Personal Property Taxes  Government Record
# 12359  County Personal Property Taxes  Government Record
# 12360  County Personal Property Taxes  Government Record
# 12361  County Personal Property Taxes  Government Record
# 12362  County Personal Property Taxes  Government Record
#
#        SourceDateYearCreated      SourceCreator SourceLocCreatedCounty  \
# 0                       1867  Cumberland County             Cumberland
# 1                       1867  Cumberland County             Cumberland
# 2                       1867  Cumberland County             Cumberland
# 3                       1867  Cumberland County             Cumberland
# 4                       1867  Cumberland County             Cumberland
# ...                      ...                ...                    ...
# 12358                   1867      Orange County                 Orange
# 12359                   1867      Orange County                 Orange
# 12360                   1867      Orange County                 Orange
# 12361                   1867      Orange County                 Orange
# 12362                   1867      Orange County                 Orange
#
#       SourceAuthorName                      EventTitle  ...  \
# 0            R B Trent  Personal Property Tax Recorded  ...
# 1            R B Trent  Personal Property Tax Recorded  ...
# 2            R B Trent  Personal Property Tax Recorded  ...
# 3            R B Trent  Personal Property Tax Recorded  ...
# 4            R B Trent  Personal Property Tax Recorded  ...
# ...                ...                             ...  ...
# 12358       G W Wright  Personal Property Tax Recorded  ...
# 12359       G W Wright  Personal Property Tax Recorded  ...
# 12360       G W Wright  Personal Property Tax Recorded  ...
# 12361       G W Wright  Personal Property Tax Recorded  ...
# 12362       G W Wright  Personal Property Tax Recorded  ...
#
#       PersonTaxSalariesSchE  PersonTaxOysterSales PersonTaxStateAll  \
# 0                       NaN                   NaN              1.65
# 1                       NaN                   NaN              1.68
# 2                       NaN                   NaN              1.25
# 3                       NaN                   NaN               1.7
# 4                       NaN                   NaN              3.42
# ...                     ...                   ...               ...
# 12358                   NaN                   NaN               0.6
# 12359                   NaN                   NaN               0.6
# 12360                   NaN                   NaN               0.6
# 12361                   NaN                   NaN               0.6
# 12362                   NaN                   NaN               0.6
#
#       PersonTaxStocksBonds PersonTaxCountWMalesover16  \
# 0                      NaN                          1
# 1                      NaN                          2
# 2                      NaN                          3
# 3                      NaN                        NaN
# 4                      NaN                          1
# ...                    ...                        ...
# 12358                  NaN                        NaN
# 12359                  NaN                        NaN
# 12360                  NaN                        NaN
# 12361                  NaN                        NaN
# 12362                  NaN                        NaN
#
#       PersonTaxCountNMalesover16 PersonTaxLeviedLand  \
# 0                            NaN                  41
# 1                            NaN                  42
# 2                            NaN                  31
# 3                            NaN                  42
# 4                            NaN                  85
# ...                          ...                 ...
# 12358                        NaN                 NaN
# 12359                        NaN                 NaN
# 12360                        NaN                 NaN
# 12361                        NaN                 NaN
# 12362                        NaN                 NaN
#
#       PersonTaxTotalCountyValue PersonTaxCommissionerRemarks  \
# 0                          1.41                          NaN
# 1                          2.42                          NaN
# 2                          3.31                          NaN
# 3                          0.42                          NaN
# 4                          1.85                          NaN
# ...                         ...                          ...
# 12358                       NaN                          NaN
# 12359                       NaN                          NaN
# 12360                       NaN                          NaN
# 12361                       NaN                          NaN
# 12362                       NaN                          NaN
#
#                                           EventImageLink
# 0      https://onesharedstory.org/HBCP/files/original...
# 1      https://onesharedstory.org/HBCP/files/original...
# 2      https://onesharedstory.org/HBCP/files/original...
# 3      https://onesharedstory.org/HBCP/files/original...
# 4      https://onesharedstory.org/HBCP/files/original...
# ...                                                  ...
# 12358  https://onesharedstory.org/HBCP/files/original...
# 12359  https://onesharedstory.org/HBCP/files/original...
# 12360  https://onesharedstory.org/HBCP/files/original...
# 12361  https://onesharedstory.org/HBCP/files/original...
# 12362  https://onesharedstory.org/HBCP/files/original...
#
# [12363 rows x 70 columns]

# %%
data.columns
# Out:
# Index(['SourceSteward', 'SourceLocCity', 'SourceLocState', 'SourceTitle',
#        'SourceType', 'SourceDateYearCreated', 'SourceCreator',
#        'SourceLocCreatedCounty', 'SourceAuthorName', 'EventTitle',
#        'EventLocJurisdictionCounty', 'EventDateYear', 'EventTranscriberNotes',
#        'PersonSurname', 'PersonGivenNames', 'PersonNameAlternate',
#        'PersonNameSuffix', 'PersonEventRole', 'PersonFN',
#        'PersonsTaxedCountWMalesover21', 'PersonsTaxedCountNMalesover21',
#        'PersonRoleLocSurnameEmployer', 'PersonRoleGivenNamesEmployer',
#        'PersonAlternateNameEmployer', 'PersonRoleNameSuffixEmployer',
#        'PersonRoleLocEmployment', 'PersonRoleLocResidence',
#        'PersonTaxCountHorsesMules', 'PersonTaxValueHorsesMules',
#        'PersonTaxCountCattle', 'PersonTaxValueCattle', 'PersonTaxCountSheep',
#        'PersonTaxValueSheep', 'PersonTaxCountHogs', 'PersonTaxValueHogs',
#        'PersonTaxCountCarriageWagon', 'PersonTaxValueCarriageWagon',
#        'PersonTaxCountWatches', 'PersonTaxValueWatches',
#        'PersonTaxCountClocks', 'PersonTaxValueClocks',
#        'PersonTaxCountMusicalInstruments', 'PersonTaxValueMusicalInstruments',
#        'PersonTaxValueFurnishings', 'PersonTaxValueJewelry',
#        'PersonTaxValueAgProducts', 'PersonTaxValueWatercraft',
#        'PersonTaxValueMoniesSchC1', 'PersonTaxValueStockCosSchC2',
#        'PersonTaxValueLicensedBusinessSchC3',
#        'PersonTaxValueJudgementReceivershipSchC4',
#        'PersonTaxValueJudgementsSchC5', 'PersonTaxValueIncomeRentTollsSchC6',
#        'PersonTaxValueAggregatePersonlProperty', 'Unnamed: 54', 'Unnamed: 55',
#        'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59',
#        'PersonTaxSalariesSchE', 'PersonTaxOysterSales', 'PersonTaxStateAll',
#        'PersonTaxStocksBonds', 'PersonTaxCountWMalesover16',
#        'PersonTaxCountNMalesover16', 'PersonTaxLeviedLand',
#        'PersonTaxTotalCountyValue', 'PersonTaxCommissionerRemarks',
#        'EventImageLink'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12363 entries, 0 to 12362
# Data columns (total 70 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   SourceSteward                             12363 non-null  object
#  1   SourceLocCity                             12363 non-null  object
#  2   SourceLocState                            12363 non-null  object
#  3   SourceTitle                               12363 non-null  object
#  4   SourceType                                12363 non-null  object
#  5   SourceDateYearCreated                     12363 non-null  int64
#  6   SourceCreator                             12363 non-null  object
#  7   SourceLocCreatedCounty                    12363 non-null  object
#  8   SourceAuthorName                          12363 non-null  object
#  9   EventTitle                                12363 non-null  object
#  10  EventLocJurisdictionCounty                12363 non-null  object
#  11  EventDateYear                             12363 non-null  int64
#  12  EventTranscriberNotes                     2092 non-null   object
#  13  PersonSurname                             12361 non-null  object
#  14  PersonGivenNames                          12327 non-null  object
#  15  PersonNameAlternate                       1097 non-null   object
#  16  PersonNameSuffix                          2648 non-null   object
#  17  PersonEventRole                           12363 non-null  object
#  18  PersonFN                                  2077 non-null   object
#  19  PersonsTaxedCountWMalesover21             6086 non-null   object
#  20  PersonsTaxedCountNMalesover21             7359 non-null   object
#  21  PersonRoleLocSurnameEmployer              6844 non-null   object
#  22  PersonRoleGivenNamesEmployer              6606 non-null   object
#  23  PersonAlternateNameEmployer               285 non-null    object
#  24  PersonRoleNameSuffixEmployer              2610 non-null   object
#  25  PersonRoleLocEmployment                   2324 non-null   object
#  26  PersonRoleLocResidence                    2485 non-null   object
#  27  PersonTaxCountHorsesMules                 5063 non-null   object
#  28  PersonTaxValueHorsesMules                 5068 non-null   object
#  29  PersonTaxCountCattle                      5424 non-null   object
#  30  PersonTaxValueCattle                      5422 non-null   object
#  31  PersonTaxCountSheep                       3164 non-null   object
#  32  PersonTaxValueSheep                       3162 non-null   object
#  33  PersonTaxCountHogs                        4979 non-null   object
#  34  PersonTaxValueHogs                        4996 non-null   object
#  35  PersonTaxCountCarriageWagon               3096 non-null   object
#  36  PersonTaxValueCarriageWagon               3084 non-null   object
#  37  PersonTaxCountWatches                     2627 non-null   object
#  38  PersonTaxValueWatches                     3066 non-null   object
#  39  PersonTaxCountClocks                      2722 non-null   object
#  40  PersonTaxValueClocks                      3270 non-null   object
#  41  PersonTaxCountMusicalInstruments          2254 non-null   object
#  42  PersonTaxValueMusicalInstruments          2451 non-null   object
#  43  PersonTaxValueFurnishings                 5440 non-null   object
#  44  PersonTaxValueJewelry                     2579 non-null   object
#  45  PersonTaxValueAgProducts                  2074 non-null   object
#  46  PersonTaxValueWatercraft                  2089 non-null   object
#  47  PersonTaxValueMoniesSchC1                 2068 non-null   object
#  48  PersonTaxValueStockCosSchC2               2065 non-null   object
#  49  PersonTaxValueLicensedBusinessSchC3       2067 non-null   object
#  50  PersonTaxValueJudgementReceivershipSchC4  2066 non-null   object
#  51  PersonTaxValueJudgementsSchC5             2066 non-null   object
#  52  PersonTaxValueIncomeRentTollsSchC6        2078 non-null   object
#  53  PersonTaxValueAggregatePersonlProperty    6138 non-null   object
#  54  Unnamed: 54                               2084 non-null   object
#  55  Unnamed: 55                               2068 non-null   object
#  56  Unnamed: 56                               2065 non-null   object
#  57  Unnamed: 57                               2065 non-null   object
#  58  Unnamed: 58                               2065 non-null   object
#  59  Unnamed: 59                               2067 non-null   object
#  60  PersonTaxSalariesSchE                     2070 non-null   object
#  61  PersonTaxOysterSales                      2065 non-null   object
#  62  PersonTaxStateAll                         12114 non-null  object
#  63  PersonTaxStocksBonds                      2131 non-null   object
#  64  PersonTaxCountWMalesover16                2630 non-null   object
#  65  PersonTaxCountNMalesover16                3319 non-null   object
#  66  PersonTaxLeviedLand                       3795 non-null   object
#  67  PersonTaxTotalCountyValue                 3845 non-null   object
#  68  PersonTaxCommissionerRemarks              2152 non-null   object
#  69  EventImageLink                            12363 non-null  object
# dtypes: int64(2), object(68)
# memory usage: 6.6+ MB

# %%
data = data.fillna('')

# %%
data
# Out:
#              SourceSteward SourceLocCity SourceLocState  \
# 0      Library of Virginia      Richmond       Virginia
# 1      Library of Virginia      Richmond       Virginia
# 2      Library of Virginia      Richmond       Virginia
# 3      Library of Virginia      Richmond       Virginia
# 4      Library of Virginia      Richmond       Virginia
# ...                    ...           ...            ...
# 12358  Library of Virginia      Richmond       Virginia
# 12359  Library of Virginia      Richmond       Virginia
# 12360  Library of Virginia      Richmond       Virginia
# 12361  Library of Virginia      Richmond       Virginia
# 12362  Library of Virginia      Richmond       Virginia
#
#                           SourceTitle         SourceType  \
# 0      County Personal Property Taxes  Government Record
# 1      County Personal Property Taxes  Government Record
# 2      County Personal Property Taxes  Government Record
# 3      County Personal Property Taxes  Government Record
# 4      County Personal Property Taxes  Government Record
# ...                               ...                ...
# 12358  County Personal Property Taxes  Government Record
# 12359  County Personal Property Taxes  Government Record
# 12360  County Personal Property Taxes  Government Record
# 12361  County Personal Property Taxes  Government Record
# 12362  County Personal Property Taxes  Government Record
#
#        SourceDateYearCreated      SourceCreator SourceLocCreatedCounty  \
# 0                       1867  Cumberland County             Cumberland
# 1                       1867  Cumberland County             Cumberland
# 2                       1867  Cumberland County             Cumberland
# 3                       1867  Cumberland County             Cumberland
# 4                       1867  Cumberland County             Cumberland
# ...                      ...                ...                    ...
# 12358                   1867      Orange County                 Orange
# 12359                   1867      Orange County                 Orange
# 12360                   1867      Orange County                 Orange
# 12361                   1867      Orange County                 Orange
# 12362                   1867      Orange County                 Orange
#
#       SourceAuthorName                      EventTitle  ...  \
# 0            R B Trent  Personal Property Tax Recorded  ...
# 1            R B Trent  Personal Property Tax Recorded  ...
# 2            R B Trent  Personal Property Tax Recorded  ...
# 3            R B Trent  Personal Property Tax Recorded  ...
# 4            R B Trent  Personal Property Tax Recorded  ...
# ...                ...                             ...  ...
# 12358       G W Wright  Personal Property Tax Recorded  ...
# 12359       G W Wright  Personal Property Tax Recorded  ...
# 12360       G W Wright  Personal Property Tax Recorded  ...
# 12361       G W Wright  Personal Property Tax Recorded  ...
# 12362       G W Wright  Personal Property Tax Recorded  ...
#
#       PersonTaxSalariesSchE  PersonTaxOysterSales PersonTaxStateAll  \
# 0                                                              1.65
# 1                                                              1.68
# 2                                                              1.25
# 3                                                               1.7
# 4                                                              3.42
# ...                     ...                   ...               ...
# 12358                                                           0.6
# 12359                                                           0.6
# 12360                                                           0.6
# 12361                                                           0.6
# 12362                                                           0.6
#
#       PersonTaxStocksBonds PersonTaxCountWMalesover16  \
# 0                                                   1
# 1                                                   2
# 2                                                   3
# 3
# 4                                                   1
# ...                    ...                        ...
# 12358
# 12359
# 12360
# 12361
# 12362
#
#       PersonTaxCountNMalesover16 PersonTaxLeviedLand  \
# 0                                                 41
# 1                                                 42
# 2                                                 31
# 3                                                 42
# 4                                                 85
# ...                          ...                 ...
# 12358
# 12359
# 12360
# 12361
# 12362
#
#       PersonTaxTotalCountyValue PersonTaxCommissionerRemarks  \
# 0                          1.41
# 1                          2.42
# 2                          3.31
# 3                          0.42
# 4                          1.85
# ...                         ...                          ...
# 12358
# 12359
# 12360
# 12361
# 12362
#
#                                           EventImageLink
# 0      https://onesharedstory.org/HBCP/files/original...
# 1      https://onesharedstory.org/HBCP/files/original...
# 2      https://onesharedstory.org/HBCP/files/original...
# 3      https://onesharedstory.org/HBCP/files/original...
# 4      https://onesharedstory.org/HBCP/files/original...
# ...                                                  ...
# 12358  https://onesharedstory.org/HBCP/files/original...
# 12359  https://onesharedstory.org/HBCP/files/original...
# 12360  https://onesharedstory.org/HBCP/files/original...
# 12361  https://onesharedstory.org/HBCP/files/original...
# 12362  https://onesharedstory.org/HBCP/files/original...
#
# [12363 rows x 70 columns]

# %% [markdown]
# ### EventLocJurisdictionCounty

# %%
data['EventLocJurisdictionCounty'].value_counts()   # doesn't change
# Out:
# Buckingham    3216
# Louisa        3017
# Orange        2210
# Fluvanna      2065
# Cumberland    1795
# Louisa          60
# Name: EventLocJurisdictionCounty, dtype: int64

# %%
data.loc[data['EventLocJurisdictionCounty'] == 'Louisa ', 'EventLocJurisdictionCounty'] = 'Louisa'

# %%
data['EventLocJurisdictionCounty'].value_counts()
# Out:
# Buckingham    3216
# Louisa        3077
# Orange        2210
# Fluvanna      2065
# Cumberland    1795
# Name: EventLocJurisdictionCounty, dtype: int64

# %% [markdown]
# ### Trying to See Links

# %%
data['SourceType'].value_counts()
# Out:
# Government Record    12363
# Name: SourceType, dtype: int64

# %%
data.loc[data['SourceAuthorName'] == 'G W Wright'][['EventDateYear', 'EventImageLink']]
# Out:
#        EventDateYear                                     EventImageLink
# 10153           1867  https://onesharedstory.org/HBCP/files/original...
# 10154           1867  https://onesharedstory.org/HBCP/files/original...
# 10155           1867  https://onesharedstory.org/HBCP/files/original...
# 10156           1867  https://onesharedstory.org/HBCP/files/original...
# 10157           1867  https://onesharedstory.org/HBCP/files/original...
# ...              ...                                                ...
# 12358           1867  https://onesharedstory.org/HBCP/files/original...
# 12359           1867  https://onesharedstory.org/HBCP/files/original...
# 12360           1867  https://onesharedstory.org/HBCP/files/original...
# 12361           1867  https://onesharedstory.org/HBCP/files/original...
# 12362           1867  https://onesharedstory.org/HBCP/files/original...
#
# [2109 rows x 2 columns]

# %% [markdown]
# Links are broken! Oh well.

# %% [markdown]
# ### Replacing 0s with "" Where Appropriate

# %%
(data['PersonNameAlternate'] == '0').sum()
# Out:
# 0

# %%
data['PersonNameAlternate'].value_counts()
# Out:
#                11266
# William          124
# George            69
# John              39
# James             33
#                ...
# Robert D           1
# Robert A           1
# Robert B           1
# Elizabeth A        1
# Maurice            1
# Name: PersonNameAlternate, Length: 298, dtype: int64

# %% [markdown]
# ### Output

# %%
data
# Out:
#              SourceSteward SourceLocCity SourceLocState  \
# 0      Library of Virginia      Richmond       Virginia
# 1      Library of Virginia      Richmond       Virginia
# 2      Library of Virginia      Richmond       Virginia
# 3      Library of Virginia      Richmond       Virginia
# 4      Library of Virginia      Richmond       Virginia
# ...                    ...           ...            ...
# 12358  Library of Virginia      Richmond       Virginia
# 12359  Library of Virginia      Richmond       Virginia
# 12360  Library of Virginia      Richmond       Virginia
# 12361  Library of Virginia      Richmond       Virginia
# 12362  Library of Virginia      Richmond       Virginia
#
#                           SourceTitle         SourceType  \
# 0      County Personal Property Taxes  Government Record
# 1      County Personal Property Taxes  Government Record
# 2      County Personal Property Taxes  Government Record
# 3      County Personal Property Taxes  Government Record
# 4      County Personal Property Taxes  Government Record
# ...                               ...                ...
# 12358  County Personal Property Taxes  Government Record
# 12359  County Personal Property Taxes  Government Record
# 12360  County Personal Property Taxes  Government Record
# 12361  County Personal Property Taxes  Government Record
# 12362  County Personal Property Taxes  Government Record
#
#        SourceDateYearCreated      SourceCreator SourceLocCreatedCounty  \
# 0                       1867  Cumberland County             Cumberland
# 1                       1867  Cumberland County             Cumberland
# 2                       1867  Cumberland County             Cumberland
# 3                       1867  Cumberland County             Cumberland
# 4                       1867  Cumberland County             Cumberland
# ...                      ...                ...                    ...
# 12358                   1867      Orange County                 Orange
# 12359                   1867      Orange County                 Orange
# 12360                   1867      Orange County                 Orange
# 12361                   1867      Orange County                 Orange
# 12362                   1867      Orange County                 Orange
#
#       SourceAuthorName                      EventTitle  ...  \
# 0            R B Trent  Personal Property Tax Recorded  ...
# 1            R B Trent  Personal Property Tax Recorded  ...
# 2            R B Trent  Personal Property Tax Recorded  ...
# 3            R B Trent  Personal Property Tax Recorded  ...
# 4            R B Trent  Personal Property Tax Recorded  ...
# ...                ...                             ...  ...
# 12358       G W Wright  Personal Property Tax Recorded  ...
# 12359       G W Wright  Personal Property Tax Recorded  ...
# 12360       G W Wright  Personal Property Tax Recorded  ...
# 12361       G W Wright  Personal Property Tax Recorded  ...
# 12362       G W Wright  Personal Property Tax Recorded  ...
#
#       PersonTaxSalariesSchE  PersonTaxOysterSales PersonTaxStateAll  \
# 0                                                              1.65
# 1                                                              1.68
# 2                                                              1.25
# 3                                                               1.7
# 4                                                              3.42
# ...                     ...                   ...               ...
# 12358                                                           0.6
# 12359                                                           0.6
# 12360                                                           0.6
# 12361                                                           0.6
# 12362                                                           0.6
#
#       PersonTaxStocksBonds PersonTaxCountWMalesover16  \
# 0                                                   1
# 1                                                   2
# 2                                                   3
# 3
# 4                                                   1
# ...                    ...                        ...
# 12358
# 12359
# 12360
# 12361
# 12362
#
#       PersonTaxCountNMalesover16 PersonTaxLeviedLand  \
# 0                                                 41
# 1                                                 42
# 2                                                 31
# 3                                                 42
# 4                                                 85
# ...                          ...                 ...
# 12358
# 12359
# 12360
# 12361
# 12362
#
#       PersonTaxTotalCountyValue PersonTaxCommissionerRemarks  \
# 0                          1.41
# 1                          2.42
# 2                          3.31
# 3                          0.42
# 4                          1.85
# ...                         ...                          ...
# 12358
# 12359
# 12360
# 12361
# 12362
#
#                                           EventImageLink
# 0      https://onesharedstory.org/HBCP/files/original...
# 1      https://onesharedstory.org/HBCP/files/original...
# 2      https://onesharedstory.org/HBCP/files/original...
# 3      https://onesharedstory.org/HBCP/files/original...
# 4      https://onesharedstory.org/HBCP/files/original...
# ...                                                  ...
# 12358  https://onesharedstory.org/HBCP/files/original...
# 12359  https://onesharedstory.org/HBCP/files/original...
# 12360  https://onesharedstory.org/HBCP/files/original...
# 12361  https://onesharedstory.org/HBCP/files/original...
# 12362  https://onesharedstory.org/HBCP/files/original...
#
# [12363 rows x 70 columns]

# %%
data.to_csv('Tax_Record_1867.csv', index=False)
