# %% [markdown]
# # Metadata
#
# ### Title: AK_clean
# ### Author: Ami Kano
# ### Date: March 12, 2023
#
# #### Comments:
# This is an attempt at cleaning the given data.

# %% [markdown]
# ## Set-up

# %%
from pymongo import MongoClient
import numpy as np
import pandas as pd

# %%
# URI is specific to Ami's login credentials
uri = "mongodb+srv://DS6013_Students_Ami:DS6013_Students_AK@countyrecords.4cdfgz2.mongodb.net/?retryWrites=true&w=majority"

# connect to database
client = MongoClient(uri)
database = client['TaxRecords']

# %%
database.list_collection_names()
# Out:
# ['Tax_Record_1867', 'Tax_Record_1782']

# %%
record_1867 = pd.DataFrame(list(database['Tax_Record_1867'].find()))
record_1782 = pd.DataFrame(list(database['Tax_Record_1782'].find()))

# %% [markdown]
# ## Cleaning/Preparing Data

# %%
# drop seemingly irrelevant or redundant columns

record_1867 = record_1867.drop(['_id', 'PersonTaxCountHorsesMules', 'PersonTaxValueHorsesMules',
       'PersonTaxCountCattle', 'PersonTaxValueCattle', 'PersonTaxCountSheep',
       'PersonTaxValueSheep', 'PersonTaxCountHogs', 'PersonTaxValueHogs',
       'PersonTaxCountCarriageWagon', 'PersonTaxValueCarriageWagon',
       'PersonTaxValueFurnishings', 'PersonTaxValueJewelry',
       'PersonTaxValueAggregatePersonlProperty', 'PersonTaxStateAll',
       'PersonTaxLeviedLand', 'PersonTaxTotalCountyValue', 'EventImageLink',
       'PersonsTaxedCountWMalesover21', 'PersonTaxCountWMalesover16',
       'PersonTaxCountWatches', 'PersonTaxValueWatches',
       'PersonTaxCountClocks', 'PersonTaxValueClocks',
       'PersonTaxCountMusicalInstruments', 'PersonTaxValueMusicalInstruments',
       'PersonTaxCommissionerRemarks', 'PersonsTaxedCountNMalesover21',
       'PersonTaxCountNMalesover16', 'PersonTaxValueMoniesSchC1'], axis=1)

# %%
record_1782 = record_1782.drop(['_id', 'PersonCountTaxableTithes',
       'PersonCountTaxableEnslavedPersons', 'PersonTaxCountHorsesMules',
       'PersonTaxCountCattle', 'EventArchiveLink',
       'PersonTaxCommissionerRemarks'], axis=1)

# %%
# lowercase text

for text_col in list(record_1867.select_dtypes(include=['object']).columns):
    record_1867[text_col] = record_1867[text_col].str.lower()

for text_col in list(record_1782.select_dtypes(include=['object']).columns):
    record_1782[text_col] = record_1782[text_col].str.lower()

# %%
# replace NaN with empty string

record_1867 = record_1867.fillna('')
record_1782 = record_1782.fillna('')

# %%
# make `EventTitle` the index

record_1867['EventTitle'] = "1867 "+record_1867['EventTitle'].astype(str)
record_1867 = record_1867.set_index('EventTitle')

record_1782 = record_1782.set_index('EventTitle')

# %%
record_1867.head()
# Out:
#                                            SourceSteward SourceLocCity  \
# EventTitle
# 1867 personal property tax recorded  library of virginia      richmond
# 1867 personal property tax recorded  library of virginia      richmond
# 1867 personal property tax recorded  library of virginia      richmond
# 1867 personal property tax recorded  library of virginia      richmond
# 1867 personal property tax recorded  library of virginia      richmond
#
#                                     SourceLocState  \
# EventTitle
# 1867 personal property tax recorded       virginia
# 1867 personal property tax recorded       virginia
# 1867 personal property tax recorded       virginia
# 1867 personal property tax recorded       virginia
# 1867 personal property tax recorded       virginia
#
#                                                         SourceTitle  \
# EventTitle
# 1867 personal property tax recorded  county personal property taxes
# 1867 personal property tax recorded  county personal property taxes
# 1867 personal property tax recorded  county personal property taxes
# 1867 personal property tax recorded  county personal property taxes
# 1867 personal property tax recorded  county personal property taxes
#
#                                             SourceType  SourceDateYearCreated  \
# EventTitle
# 1867 personal property tax recorded  government record                   1867
# 1867 personal property tax recorded  government record                   1867
# 1867 personal property tax recorded  government record                   1867
# 1867 personal property tax recorded  government record                   1867
# 1867 personal property tax recorded  government record                   1867
#
#                                          SourceCreator SourceLocCreatedCounty  \
# EventTitle
# 1867 personal property tax recorded  cumberland county             cumberland
# 1867 personal property tax recorded  cumberland county             cumberland
# 1867 personal property tax recorded  cumberland county             cumberland
# 1867 personal property tax recorded  cumberland county             cumberland
# 1867 personal property tax recorded  cumberland county             cumberland
#
#                                     SourceAuthorName  \
# EventTitle
# 1867 personal property tax recorded        r b trent
# 1867 personal property tax recorded        r b trent
# 1867 personal property tax recorded        r b trent
# 1867 personal property tax recorded        r b trent
# 1867 personal property tax recorded        r b trent
#
#                                     EventLocJurisdictionCounty  EventDateYear  \
# EventTitle
# 1867 personal property tax recorded                 cumberland           1867
# 1867 personal property tax recorded                 cumberland           1867
# 1867 personal property tax recorded                 cumberland           1867
# 1867 personal property tax recorded                 cumberland           1867
# 1867 personal property tax recorded                 cumberland           1867
#
#                                     PersonSurname PersonGivenNames  \
# EventTitle
# 1867 personal property tax recorded      alderson           thomas
# 1867 personal property tax recorded         allen         joseph l
# 1867 personal property tax recorded         allen           benj a
# 1867 personal property tax recorded       amonett            jno t
# 1867 personal property tax recorded      anderson          charles
#
#                                     PersonNameSuffix PersonEventRole  \
# EventTitle
# 1867 personal property tax recorded              est        taxpayer
# 1867 personal property tax recorded                         taxpayer
# 1867 personal property tax recorded                         taxpayer
# 1867 personal property tax recorded                         taxpayer
# 1867 personal property tax recorded                         taxpayer
#
#                                     PersonNameAlternate  \
# EventTitle
# 1867 personal property tax recorded
# 1867 personal property tax recorded
# 1867 personal property tax recorded          benjamin a
# 1867 personal property tax recorded              john t
# 1867 personal property tax recorded
#
#                                     PersonRoleLocSurnameEmployer  \
# EventTitle
# 1867 personal property tax recorded
# 1867 personal property tax recorded
# 1867 personal property tax recorded
# 1867 personal property tax recorded
# 1867 personal property tax recorded
#
#                                     PersonRoleGivenNamesEmployer  \
# EventTitle
# 1867 personal property tax recorded
# 1867 personal property tax recorded
# 1867 personal property tax recorded
# 1867 personal property tax recorded
# 1867 personal property tax recorded
#
#                                     PersonRoleLocResidence
# EventTitle
# 1867 personal property tax recorded
# 1867 personal property tax recorded
# 1867 personal property tax recorded
# 1867 personal property tax recorded
# 1867 personal property tax recorded

# %%
record_1782.head()
# Out:
#                                                                      SourceSteward  \
# EventTitle
# caleb stone personal property tax recorded      fluvanna county historical society
# william bernard personal property tax recorded  fluvanna county historical society
# caleb stone personal property tax recorded      fluvanna county historical society
# john ashlin personal property tax recorded      fluvanna county historical society
# john ashlin personal property tax recorded      fluvanna county historical society
#
#                                                SourceLocCity SourceLocState  \
# EventTitle
# caleb stone personal property tax recorded           palmyra       virginia
# william bernard personal property tax recorded       palmyra       virginia
# caleb stone personal property tax recorded           palmyra       virginia
# john ashlin personal property tax recorded           palmyra       virginia
# john ashlin personal property tax recorded           palmyra       virginia
#
#                                                                    SourceTitle  \
# EventTitle
# caleb stone personal property tax recorded      county personal property taxes
# william bernard personal property tax recorded  county personal property taxes
# caleb stone personal property tax recorded      county personal property taxes
# john ashlin personal property tax recorded      county personal property taxes
# john ashlin personal property tax recorded      county personal property taxes
#
#                                                        SourceType  \
# EventTitle
# caleb stone personal property tax recorded      government record
# william bernard personal property tax recorded  government record
# caleb stone personal property tax recorded      government record
# john ashlin personal property tax recorded      government record
# john ashlin personal property tax recorded      government record
#
#                                                 SourceDateYearCreated  \
# EventTitle
# caleb stone personal property tax recorded                       1782
# william bernard personal property tax recorded                   1782
# caleb stone personal property tax recorded                       1782
# john ashlin personal property tax recorded                       1782
# john ashlin personal property tax recorded                       1782
#
#                                                   SourceCreator  \
# EventTitle
# caleb stone personal property tax recorded      fluvanna county
# william bernard personal property tax recorded  fluvanna county
# caleb stone personal property tax recorded      fluvanna county
# john ashlin personal property tax recorded      fluvanna county
# john ashlin personal property tax recorded      fluvanna county
#
#                                                SourceLocCreatedCounty  \
# EventTitle
# caleb stone personal property tax recorded                   fluvanna
# william bernard personal property tax recorded               fluvanna
# caleb stone personal property tax recorded                   fluvanna
# john ashlin personal property tax recorded                   fluvanna
# john ashlin personal property tax recorded                   fluvanna
#
#                                                SourceAuthorName  \
# EventTitle
# caleb stone personal property tax recorded            jos haden
# william bernard personal property tax recorded        jos haden
# caleb stone personal property tax recorded            jos haden
# john ashlin personal property tax recorded            jos haden
# john ashlin personal property tax recorded            jos haden
#
#                                                EventLocJurisdictionCounty  \
# EventTitle
# caleb stone personal property tax recorded                fluvanna county
# william bernard personal property tax recorded            fluvanna county
# caleb stone personal property tax recorded                fluvanna county
# john ashlin personal property tax recorded                fluvanna county
# john ashlin personal property tax recorded                fluvanna county
#
#                                                 EventDateYear PersonSurname  \
# EventTitle
# caleb stone personal property tax recorded               1782         stone
# william bernard personal property tax recorded           1782
# caleb stone personal property tax recorded               1782
# john ashlin personal property tax recorded               1782
# john ashlin personal property tax recorded               1782
#
#                                                PersonGivenNames  \
# EventTitle
# caleb stone personal property tax recorded                caleb
# william bernard personal property tax recorded           hannah
# caleb stone personal property tax recorded                  sue
# john ashlin personal property tax recorded                 dick
# john ashlin personal property tax recorded                  sam
#
#                                                PersonRaceNotation  \
# EventTitle
# caleb stone personal property tax recorded                      w
# william bernard personal property tax recorded                 nn
# caleb stone personal property tax recorded                      n
# john ashlin personal property tax recorded                      n
# john ashlin personal property tax recorded                      n
#
#                                                          PersonEventRole  \
# EventTitle
# caleb stone personal property tax recorded                     tax payer
# william bernard personal property tax recorded  person taxed as property
# caleb stone personal property tax recorded      person taxed as property
# john ashlin personal property tax recorded      person taxed as property
# john ashlin personal property tax recorded      person taxed as property
#
#                                                PersonNameSuffix
# EventTitle
# caleb stone personal property tax recorded
# william bernard personal property tax recorded
# caleb stone personal property tax recorded
# john ashlin personal property tax recorded
# john ashlin personal property tax recorded
